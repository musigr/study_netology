# %% [markdown]
# <a href="https://colab.research.google.com/github/musigr/study_netology/blob/main/Pandas/4_Parsing/Parsing6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
list = ['python', 'аналитик данных']

# %%
params = {'q': "list",
          'target_type': 'posts',
          'order': 'relevance'}
          
URL = 'https://habr.com/ru/search/'

res = requests.get(URL, params)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D">\n<head >\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width,initial-scale=1.0,viewport-fit=cover">\n  <meta name="referrer" content="unsafe-url">\n  <title>Результаты поиска по запросу «list» / Хабр</title>\n  <style>\n    /* cyrillic-ext */\n    @font-face {\n      font-family: \'Fira Sans\';\n      font-style: normal;\n      font-weight: 500;\n      font-display: swap;\n      src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format(\'woff2\');\n      unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;\n    }\n\n    /* cyrillic */\n    @font-face {\n      font-family: \'Fira Sans\';\n      font-style: normal;\n      font-weight: 500;\n      font-display: swap;\n      src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format(\'woff2\');\n      unicode-ra
# ...

# %%
soup = BeautifulSoup(res.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,viewport-fit=cover" name="viewport"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>Результаты поиска по запросу «list» / Хабр</title>
# <style>
#     /* cyrillic-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format('woff2');
#       unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
#     }
#
#     /* cyrillic */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format('woff2');
# ...

# %%
time_blocks = soup.find_all("time")
time_blocks
# Out:
# [<time datetime="2021-04-13T12:39:17.000Z" title="2021-04-13, 15:39">13  апреля  2021 в 15:39</time>,
#  <time datetime="2014-02-10T09:19:32.000Z" title="2014-02-10, 13:19">10  февраля  2014 в 13:19</time>,
#  <time datetime="2020-03-15T09:13:34.000Z" title="2020-03-15, 12:13">15  марта  2020 в 12:13</time>,
#  <time datetime="2018-02-26T07:58:56.000Z" title="2018-02-26, 10:58">26  февраля  2018 в 10:58</time>,
#  <time datetime="2015-03-10T06:00:30.000Z" title="2015-03-10, 09:00">10  марта  2015 в 09:00</time>,
#  <time datetime="2013-02-03T17:18:01.000Z" title="2013-02-03, 21:18">3  февраля  2013 в 21:18</time>,
#  <time datetime="2019-12-08T19:05:03.000Z" title="2019-12-08, 22:05">8  декабря  2019 в 22:05</time>,
#  <time datetime="2009-08-25T15:21:40.000Z" title="2009-08-25, 19:21">25  августа  2009 в 19:21</time>,
#  <time datetime="2012-08-10T10:17:37.000Z" title="2012-08-10, 14:17">10  августа  2012 в 14:17</time>,
# ...

# %%
for i in range(len(time_blocks)):
    dte = time_blocks[i]['title'][:10]
   
    print(dte)
# Out:
# 2021-04-13
# 2014-02-10
# 2020-03-15
# 2018-02-26
# 2015-03-10
# 2013-02-03
# 2019-12-08
# 2009-08-25
# 2012-08-10
# 2015-07-27
# 2009-05-29
# 2007-08-06
# 2007-10-31
# 2008-10-07
# 2011-12-07
# 2012-08-20
# 2015-12-08
# 2010-08-24
# 2011-01-19
# 2011-12-07

# %%
link_blocks = soup.find_all("a", class_="tm-article-snippet__title-link")
link_blocks
# Out:
# [<a class="tm-article-snippet__title-link" data-article-link="" href="/ru/news/t/552204/"><span>Число заявок на включение в Public Suffix <em class="searched-item">List</em> резко подскочило из-за изменений приватности в Apple iOS 14.5</span></a>,
#  <a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/212049/"><span>Управления процессом обмена маршрутными обновлениями с помощью списков префиксов (prefix-<em class="searched-item">list</em>)</span></a>,
#  <a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/492346/"><span>Linked <em class="searched-item">List</em> Implementation in JavaScript | Data Structure and Algorithm</span></a>,
#  <a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/349944/"><span><em class="searched-item">List</em>.of() и все, все, все…</span></a>,
# ...

# %%
for i in range(len(link_blocks)):
    lnk = "https://habr.com"+link_blocks[i]['href']
  
    print(lnk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a047709fd56e> in <module>()
# ----> 1 for i in range(len(link_blocks)):
#       2     lnk = "https://habr.com"+link_blocks[i]['href']
#       3
#       4     print(lnk)
#
# NameError: name 'link_blocks' is not defined

# %%
for j in range(len(link_blocks)):
     ttl = str(link_blocks[j].span)[6:][:-7].replace('</em>','').replace('<em class="searched-item">', '')
     print(ttl)
# Out:
# Число заявок на включение в Public Suffix List резко подскочило из-за изменений приватности в Apple iOS 14.5
# Управления процессом обмена маршрутными обновлениями с помощью списков префиксов (prefix-list)
# Linked List Implementation in JavaScript | Data Structure and Algorithm
# List.of() и все, все, все…
# Lock-free структуры данных. Concurrent maps: skip list
# DoubleArrayList — универсальная реализация java.util.List
# List Comprehension vs Map
# Нерекурсивная выборка всего дерева Adjacency List
# Неприятная особенность std::list, о которой не все знают
# Хранение иерархических структур. Симбиоз «Closure Table» и «Adjacency List»
# Раскраска Calendar List
# Вышел Google Documents List Data API
# Жертвы поведенческого маркетинга формируют список “Do Not Track List”
# A List Apart: 10 лет
# Кроссбраузерный поиск в select list
# Unrolled linked list на Java
# Добавление jump lists в приложение UWP
# Телепрограмма на неделю для Iphone (TV-Listings Russia)
# Lists, Lists everywhere!
# ...

# %%
for i in range(len(time_blocks)-1):
     
     
     def elem(i):
         dte = time_blocks[i]['title'][:10]
         lnk = "https://habr.com"+link_blocks[i]['href']
         ttl = str(link_blocks[i].span)[6:][:-7].replace('</em>','').replace('<em class="searched-item">','')
         return [i+1, dte, ttl, lnk]
   
print(elem(19))
# Out:
# [20, '2011-12-07', 'Pocket Lists. Чеклисты для iPhone', 'https://habr.com/ru/post/134204/']

# %%
print(ar)
# Out:
# <function ar at 0x7f5cb232cef0>

# %%
def add(x, y):
    return x + y

print (add(10, 7))
# Out:
# 17

# %%
example_array = [[1, 2], [3, 4]]
example_array.append( [-1, 2])
#example_array.insert(1, [-1, 13, 64])
print(example_array)
# Out:
# [[1, 2], [3, 4], [-1, 2]]

# %%
print (type([i+1, dte, ttl, lnk]))
# Out:
# <class 'list'>

# %%
p = [[20, '2011-12-07', 'Pocket Lists. Чеклисты для iPhone', 'https://habr.com/ru/post/134204/'], [21, '2011-12-07', 'Pocket Lists. Чеклисты для iPhone', 'https://habr.com/ru/post/134204/']]
pd.DataFrame (p)
# Out:
#     0           1                                  2  \
# 0  20  2011-12-07  Pocket Lists. Чеклисты для iPhone
# 1  21  2011-12-07  Pocket Lists. Чеклисты для iPhone
#
#                                   3
# 0  https://habr.com/ru/post/134204/
# 1  https://habr.com/ru/post/134204/
